# %%
Util.downloadStockData('AAPL', date(2016, 1, 1), date(2017, 1, 1))
Util.downloadStockData('GOOG', date(2016, 1, 1), date(2017, 1, 1))

# %%
from datetime import date
import importlib
from portfolio import Portfolio
import util
import matplotlib.pyplot as plt

importlib.reload(Util)
# Out:
# <module 'Util' from '/Users/xlanzhou/Desktop/Richard/stockmanager/util.py'>

# %%
stockData = [item[4] for item in Util.getStockPrice('AAPL', date(2016, 1, 4), date(2017, 1, 1))]
plt.plot(stockData)
plt.show()

# %%
a = Util.createTrainingData('AAPL', date(2016, 1, 4), date(2017, 1, 1))
plt.plot(a)
plt.show()
# Out:
# -1.965000000000001 1.990000000000002
